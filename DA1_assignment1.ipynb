# %% [markdown]
# <a href="https://colab.research.google.com/github/bachinaram/DataAnalytics1/blob/main/DA1_assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
df = pd.read_csv('/content/sample_data/football_data.csv')
df["Height"].fillna("0'0", inplace = True) 
df['Height'].hist(bins=25)

plt.xlabel("Height in inches", labelpad=14)
plt.ylabel("Players", labelpad=14)
plt.title("Count of players based on height", y=1.015, fontsize=22);




#a=[]
#for i in df['Height']:
#  H_feet = i.split("'")[0]
#  H_inch = i.split("'")[1].split("\"")[0]
#  H_inches = int(H_feet) * 12 + int(H_inch)
#  a.append(H_inches)
#sns.set(font_scale=1.4)
#df1 = pd.DataFrame(a, columns =['Height'])
#df1['Height'].hist(bins=100)

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
df = pd.read_csv('/content/sample_data/football_data.csv')
df["Club"].fillna("No Club", inplace = True) 


#df1 = pd.DataFrame(a, columns =['Height'])
#df['Club'].hist(bins=100)


#df["Club"].value_counts().plot(kind='bar')

plt.bar(df["Overall"],df["Club"])

plt.xlabel("Overall", labelpad=104)
plt.ylabel("Club", labelpad=14)
plt.title("Overall rating of players in different clubs", y=1.015, fontsize=22);

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
df = pd.read_csv('/content/sample_data/football_data.csv')
#df["Club"].unique()

#df["Penalties"].fillna(0.0, inplace = True)
#a=[]
#for i in df["Penalties"]:
#  b=int(i)
#  a.append(b)
#x=a

df['Weight'].fillna("0", inplace = True)
d=[]

for k in df['Weight']:
  size = len(k)
  value = k[:size - 3]
  d.append(value)
z=d




b=[]
df["Position"].fillna("NoData", inplace = True) 
for j in df["Position"]:
  b.append(j)
y=b


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(y,z)




#df["Position"].value_counts().plot(kind='bar')
plt.ylabel("Weight in Pounds", labelpad=14)
plt.xlabel("Position", labelpad=14)
plt.title("Position of player based on Weight", y=1.015, fontsize=22);

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
df = pd.read_csv('/content/sample_data/football_data.csv')
x=df["Crossing"]
y=df["Finishing"]
plt.scatter(x, y)
#colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

#day one, the age and speed of 13 cars:
#x = np.array([84,84])
#y = np.array([95,94])
x=df["Vision"]
y=df["Balance"]
plt.scatter(x, y)

x=df["Curve"]
y=df["FKAccuracy"]
plt.scatter(x, y)

x=df["Overall"]
y=df["BallControl"]
plt.scatter(x, y)


x=df["LongShots"]
y=df["Composure"]
plt.scatter(x, y)




plt.xlabel("Balance, accuracy, control, composure", labelpad=14)
plt.ylabel("Vision, Curve, Overall, Longshots", labelpad=14)
plt.title("Exceptional Player[Top Right Peek] - outliers", y=1.015, fontsize=22);
